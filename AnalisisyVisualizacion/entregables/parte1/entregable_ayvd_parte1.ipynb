# %% [markdown]
# # **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# ## **Edición 2026**
#
# ---
# ## Trabajo práctico entregable - Parte 1
#
# **Materia:** Análisis y Visualización de Datos 2026
#
# **Alumno:** Rubén Rasi
#
# **Docente de seguimiento:** Fredy Restrepo Blandón

# %% [markdown]
# ## Imports y configuración

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn

seaborn.set_context('talk')

# %% [markdown]
# ## Lectura del dataset

# %%
url = 'https://raw.githubusercontent.com/DiploDatos/AnalisisyVisualizacion/master/sysarmy_survey_2026_processed.csv'
df = pd.read_csv(url)
df.shape

# %%
df.head(10)

# %% [markdown]
# ## Exploración inicial del dataset

# %%
# Dimensiones, tipos de datos y valores nulos

# %% [markdown]
# ---
# # Ejercicio 1 - Análisis descriptivo
#
# Responder a la pregunta: **¿Cuáles son los lenguajes de programación asociados a los mejores salarios?**
#
# Para ello:
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en una sub-población.
#   * Obtener una lista de los lenguajes de programación más populares. Decidir cuántos y cuáles seleccionan para incluir en el análisis.
#   * Para cada una de las otras columnas del punto anterior, elegir los rangos o valores seleccionan para incluir en el análisis.
# 3. Seleccionar métricas que ayuden a responder la pregunta, y los métodos para analizarlas.

# %% [markdown]
# ### 1.1 Selección de columnas relevantes

# %%
# Definir columnas relevantes para el análisis
relevant_columns = ['tools_programming_languages', 'salary_monthly_NETO']
# TODO: agregar más columnas si es necesario

# %% [markdown]
# ### 1.2 Selección y limpieza de filas
#
# **Justificación de los criterios de filtrado:**
#
# *(completar)*

# %%
# Limpieza: eliminar NaN, outliers, filtrar sub-población

# %% [markdown]
# ### 1.3 Conteo de frecuencias de lenguajes de programación
#
# La columna `tools_programming_languages` contiene strings con los lenguajes separados por comas.

# %%
def split_languages(languages_str):
    if not isinstance(languages_str, str):
        return []
    languages_str = languages_str.lower()\
        .replace('ninguno de los anteriores', '')
    return [lang.strip().replace(',', '')
            for lang in languages_str.split(', ')]

# %%
# Explotar lenguajes: una fila por (persona, lenguaje)

# %%
# Frecuencia de lenguajes y selección de los más populares

# %% [markdown]
# ### 1.4 Filtrado de lenguajes relevantes

# %%
# Filtrar solo los lenguajes seleccionados
interesting_languages = []  # TODO: completar

# %% [markdown]
# ### 1.5 Métricas y análisis
#
# *(Elegir UNA opción: distribuciones, estadística descriptiva o probabilidades)*

# %%
# Visualizaciones y/o métricas comparativas

# %% [markdown]
# ### 1.6 Conclusiones del Ejercicio 1
#
# *(completar)*

# %% [markdown]
# ---
# # Ejercicio 2 - Densidades y varias variables
#
# Responder a la pregunta general: **¿Qué herramientas (prácticas y teóricas) son útiles para explorar la base, descubrir patrones, asociaciones?**

# %% [markdown]
# ## 2a) Densidad conjunta
#
# Elegir tres variables numéricas y 2 variables categóricas. Visualizar la base según varias de las variables elegidas.

# %%
# Variables numéricas elegidas:
# Variables categóricas elegidas:

# %% [markdown]
# ## 2b) Asociación
#
# ¿Existe una correlación entre el salario bruto y el neto? ¿Qué abordaje y medidas usaría?

# %%
# Análisis de correlación Bruto vs Neto

# %% [markdown]
# ## 2c) Densidad condicional
#
# Estudiar la distribución del salario según el nivel de estudio. Separar la población según el nivel de estudio (elegir dos subpoblaciones numerosas) y graficar de manera comparativa ambos histogramas.

# %%
# Histogramas comparativos por nivel de estudio

# %% [markdown]
# **¿Son independientes el salario y el nivel de estudio?**
#
# *(completar)*
#
# **Medidas de centralización y dispersión por subpoblación:**

# %%
# Medidas descriptivas por nivel de estudio

# %% [markdown]
# ## 2d) Densidad conjunta condicional
#
# Elegir dos variables numéricas y una categórica. Estudiar la dispersión (scatterplot) de las dos variables discriminando en color por la variable categórica (hue en seaborn).

# %%
# Scatterplot con hue

# %% [markdown]
# ---
# ## Reflexiones finales
#
# **Hipótesis planteadas:**
#
# *(completar)*
#
# **Abordaje propuesto:**
#
# *(completar)*
